# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
V = np.array([[1,1], [-2,2], [4,-7]])
origin = np.array([[0, 0, 0],[0, 0, 0]]) # origin point

fig, ax = plt.subplots(figsize = (5, 5))
ax.quiver(*origin, V[:,0], V[:,1], color=['r','b','g'], angles='xy', scale_units='xy', scale=1)
ax.axis([-10,10,-10,10])
# Out:
# (-10.0, 10.0, -10.0, 10.0)

# %%
V = np.array([[5,0], [1,-1], [2,3], [2,7]])
O = np.array([[0,0], [0,0], [0,0], [0,0]])

fig, ax1 = plt.subplots(figsize = (5, 5))
ax1.quiver(O[:,0], O[:,1], V[:,0], V[:,1], color=['g','r','y','b'], angles='xy', scale_units='xy', scale=1)
ax1.axis([0,10,0,10])
# Out:
# (0.0, 10.0, 0.0, 10.0)

# %%
V2 = np.array([[5,0], [1,-1], [2,3], [2,7]])
O2 = np.array([[0,0], [0,0], [0,0], [0,0]])

fig, ax2 = plt.subplots(figsize = (5, 5))
ax2.quiver(O2[0,0], O2[0,1], V2[0,0], V2[0,1], color='g', angles='xy', scale_units='xy', scale=1)
ax2.quiver(V2[0,0], V2[0,1], V2[1,0], V2[1,1], color='r', angles='xy', scale_units='xy', scale=1)
ax2.quiver(V2[1,0], V2[1,1], V2[2,0], V2[2,1], color='y', angles='xy', scale_units='xy', scale=1)
ax2.quiver(V2[2,0], V2[2,1], V2[3,0], V2[3,1], color='b', angles='xy', scale_units='xy', scale=1)
# ax2.quiver(V2[0,:], V2[1,:], color='r', angles='xy', scale_units='xy', scale=1)
# ax2.quiver(V2[1,:], V2[2,:], color='y', angles='xy', scale_units='xy', scale=1)
# ax2.quiver(V2[2,:], V2[3,:], color='b', angles='xy', scale_units='xy', scale=1)
ax2.axis([-5,10,-5,10])
# Out:
# (-5.0, 10.0, -5.0, 10.0)

# %%
V[2,1]
# Out:
# 3

# %%
a = 1+1j
b = 2+3j

plt.plot(a.real, a.imag, 'r')
plt.plot(b.real, b.imag, 'b')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
b.imag
# Out:
# 3.0

# %%
v1 = np.array([5,0])
v2 = np.array([1,-1])
v3 = np.array([2,3])
v4 = np.array([2,7])
origin = np.array([0,0])

v22 = np.add(v1, v2)
v33 = np.add(v22, v3)

fig = plt.figure(figsize = (5, 5))
plt.style.use("seaborn-v0_8-whitegrid")
ax0 = fig.add_subplot(111)
ax0.quiver(*origin, *v1, color='lightgreen', angles='xy', scale_units='xy', scale=1)
ax0.quiver(*v1, *v2, color='tomato', angles='xy', scale_units='xy', scale=1)
quiver = ax0.quiver(*v22, *v3, color='peachpuff', angles='xy', scale_units='xy', scale=1)
quiver = ax0.quiver(*origin, *v33, color='lightskyblue', angles='xy', scale_units='xy', scale=1)
ax0.axis([-5,10,-5,10])


axSlider = plt.axes([0.25, 0.1, 0.65, 0.03])
slider = Slider(axSlider, 'SLiDe', 1.0, 5.0, valinit=3.0)

def update(val):
    v3val = Slider.val
    v3 = np.array([2, v3val])
    v33 = np.add(v22, v3)
    quiver.set_UVC(*v22, *v3, color='peachpuff', angles='xy', scale_units='xy', scale=1)
    quiver.set_UVC(*origin, *v33, color='lightskyblue', angles='xy', scale_units='xy', scale=1)

slider.on_changed(update)

plt.show()



# Initialize U, V with nonzero values
initial_frequency = 1.0
U = np.sin(X * initial_frequency)
V = np.cos(Y * initial_frequency)

fig, ax = plt.subplots()
plt.subplots_adjust(left=0.25, bottom=0.25)
quiver = ax.quiver(X, Y, U, V)

axfreq = plt.axes([0.25, 0.1, 0.65, 0.03])
freq_slider = Slider(axfreq, 'Freq', 0.1, 2.0, valinit=1.0)

def update(val):
    frequency = freq_slider.val
    U = np.sin(X * frequency)
    V = np.cos(Y * frequency)
    quiver.set_UVC(U, V)

freq_slider.on_changed(update)
# Out:
# (-5.0, 10.0, -5.0, 10.0)
